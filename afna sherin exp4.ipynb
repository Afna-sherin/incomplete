# %%
#list 
colors=input("enter the colors names:")
list=colors.split(",")
print("first color:",list[0])
print("last color:",list[-1])
# Out:
# enter the colors names:red,blue,green,yellow
# first color: red
# last color: yellow

# %%
#file
filename=input("enter filename:")
extension=filename.split(".")
print("extension:",extension[-1])
# Out:
# enter filename:hello.py
# extension: py

# %%
#sum 
numbers=input("enter the numbers:")
numbers=numbers.split(",")
numbers=list(map(int,numbers))
print("list:",numbers)
print("sum:",sum(numbers))
# Out:
# enter the numbers:5 6 7 1 20 54 63 788 32566
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       2 numbers=input("enter the numbers:")
#       3 numbers=numbers.split(",")
# ----> 4 numbers=list(map(int,numbers))
#       5 print("list:",numbers)
#       6 print("sum:",sum(numbers))
#
# ValueError: invalid literal for int() with base 10: '5 6 7 1 20 54 63 788 32566'
