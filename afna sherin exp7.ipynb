# %%
#set
set1={"red","blue","green","yellow"}
set2={"blue","yellow"}
set=set1-set2
print("colors in set1 but not in set2:",set)
# Out:
# colors in set1 but not in set2: {'green', 'red'}

# %%
#set
set1={"red","purple","green"}
set2={"blue","yellow","white"}
set=set1|set2
print("all colors:",set)
# Out:
# all colors: {'yellow', 'red', 'green', 'purple', 'white', 'blue'}
